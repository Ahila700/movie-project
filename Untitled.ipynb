# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_films_based_on_video_games')

# %%
df = df[0]

# %%
df = df.drop(columns = ['Metacritic', 'Rotten Tomatoes'])
df = df.drop(df.index[38:])

# %%
int_box_office = []
for x in df['Worldwide box office']:
    int_box_office.append(int(''.join(x.split('[')[0][1:].split(','))))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-28e6eb3bcfbb> in <module>
#       1 int_box_office = []
#       2 for x in df['Worldwide box office']:
# ----> 3     int_box_office.append(int(''.join(x.split('[')[0][1:].split(','))))
#
# AttributeError: 'int' object has no attribute 'split'

# %%
df['Worldwide box office'] = int_box_office
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-379c93e07ada> in <module>
# ----> 1 df['Worldwide box office'] = int_box_office
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# ...

# %%
df.sort_values('Worldwide box office', ascending = False)
# Out:
#                                             Title        Release date  \
# 30                                       Warcraft       June 10, 2016
# 36                              Detective Pikachu        May 10, 2019
# 34                                        Rampage      April 13, 2018
# 24            Prince of Persia: The Sands of Time        May 28, 2010
# 32               Resident Evil: The Final Chapter    January 27, 2017
# 37                             Sonic the Hedgehog   February 14, 2020
# 25                       Resident Evil: Afterlife  September 10, 2010
# 6                         Lara Croft: Tomb Raider       June 15, 2001
# 33                                    Tomb Raider      March 16, 2018
# 31                               Assassin's Creed   December 21, 2016
# 26                     Resident Evil: Retribution  September 14, 2012
# 28                                 Need for Speed      March 14, 2014
# ...

# %%
df.describe()
# Out:
#        Worldwide box office
# count          3.800000e+01
# mean           1.360747e+08
# std            1.379859e+08
# min            9.232100e+04
# 25%            1.284763e+07
# 50%            9.851549e+07
# 75%            2.404201e+08
# max            4.390489e+08

# %%
df.to_csv('box_office_video_game_movies.csv')
# mean is $136,047,700 per movie
