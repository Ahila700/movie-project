# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

import seaborn as sns
sns.set(context='paper', style='darkgrid', rc={'figure.facecolor':'white'}, font_scale=1.2)

# %%
game_sales = pd.read_csv('game_sales.csv', index_col = 0)
metacritic_reviews = pd.read_csv('metacritic_reviews.csv', index_col = 0)
gamespot_reviews = pd.read_csv('gamespot_reviews.csv', index_col = 0)
gamespot_w_sales = pd.read_csv('gamespot_w_sales.csv', index_col = 0)
metacritic_w_sales = pd.read_csv('metacritic_w_sales.csv', index_col = 0)

# %%
# metacritic_wo_0 = metacritic_w_sales.loc[metacritic_w_sales['Global'] > 0]

# %%
metacritic_w_sales
# Out:
#                                      Game  metacritic_score  \
# 0                   red dead redemption 2                97
# 1    metal gear solid v: the phantom pain                95
# 2                                  inside                93
# 3                the witcher 3: wild hunt                91
# 4                          rayman legends                91
# ..                                    ...               ...
# 340                           nba live 14                36
# 341                                   fru                84
# 342               fantasia: music evolved                77
# 343                             the surge                74
# 344                mount & blade: warband                59
#
#      metacritic_review_count  user_score  user_review_count content_rating  \
# 0                         33         7.7             2413.0              M
# 1                         10         7.4             1111.0              M
# 2                         87         8.3              629.0              M
# 3                         13         9.2             4585.0              M
# 4                          6         7.9              243.0           E10+
# ..                       ...         ...                ...            ...
# 340                       14         3.1               89.0              E
# 341                       24         6.8               37.0              E
# 342                       48         7.5               70.0           E10+
# 343                       17         7.1               72.0              M
# 344                       10         7.8               40.0              T
#
#                                                 genres  release_date    Year  \
# 0                  ['Action Adventure', ' Open-World']  Oct 26, 2018  2018.0
# 1    ['Modern', ' Modern', ' Action Adventure', ' O...   Sep 1, 2015  2015.0
# 2                     ['Action', ' Platformer', ' 2D']  Jun 29, 2016     NaN
# 3       ['Action RPG', ' Role-Playing', ' Action RPG']  May 19, 2015  2015.0
# 4    ['Platformer', ' 2D', ' Action', ' Platformer'...  Feb 18, 2014  2014.0
# ..                                                 ...           ...     ...
# 340  ['Arcade', ' Sports', ' Traditional', ' Team',...  Nov 19, 2013  2013.0
# 341            ['Miscellaneous', ' Puzzle', ' Action']  Jul 13, 2016     NaN
# 342  ['Music', ' Action', ' Miscellaneous', ' Rhyth...  Oct 21, 2014  2014.0
# 343                    ['Role-Playing', ' Action RPG']  May 16, 2017  2017.0
# 344                 ['Role-Playing', ' Western-Style']  Sep 16, 2016  2016.0
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           3.76    1.47   0.00
# 1    Konami Digital Entertainment           0.49    0.25   0.02
# 2                             NaN           0.00    0.00   0.00
# 3              Namco Bandai Games           0.97    0.61   0.01
# 4                         Ubisoft           0.13    0.22   0.00
# ..                            ...            ...     ...    ...
# 340                     EA Sports           0.19    0.02   0.00
# 341                           NaN           0.00    0.00   0.00
# 342    Disney Interactive Studios           0.14    0.03   0.00
# 343                    Koch Media           0.07    0.04   0.00
# 344                    Koch Media           0.00    0.00   0.00
#
#      Rest of World  Global
# 0             0.54    5.77
# 1             0.07    0.83
# 2             0.00    0.00
# 3             0.15    1.74
# 4             0.03    0.38
# ..             ...     ...
# 340           0.02    0.24
# 341           0.00    0.00
# 342           0.02    0.19
# 343           0.01    0.12
# 344           0.00    0.00
#
# [345 rows x 15 columns]

# %%
# plot one - publisher by gobal sales

publisher_sales = metacritic_w_sales.groupby('Publisher')['Global'].describe().sort_values('count', ascending = False)[0:20]    

ax = publisher_sales.plot.bar(y = 'mean')
ax.set_ylabel('Unit sales in Millions')
ax.set_xlabel('Publisher')
ax.set_title('Top 20 Publishers vs Sales')
# Out:
# Text(0.5, 1.0, 'Top 20 Publishers vs Sales')

# %%
fig, ax = plt.subplots()

# Add data: "height", "weight" as x-y, index as color
ax.scatter(metacritic_w_sales['Global'], metacritic_w_sales['user_score'])

ax.set_xlabel("Unit sales in Millions")
ax.set_ylabel("Average User Score")
ax.set_title('Relationship between User Score and Sales')


plt.show()

# %%
metacritic_w_sales[['Global', 'user_score']].corr()
# Out:
#               Global  user_score
# Global      1.000000   -0.055728
# user_score -0.055728    1.000000

# %%
fig, ax = plt.subplots()

# Add data: "height", "weight" as x-y, index as color
ax.scatter(metacritic_w_sales['Global'], metacritic_w_sales['user_review_count'])

ax.set_xlabel("Unit sales in Millions")
ax.set_ylabel("Average User Review Count")
ax.set_title('Relationship between User Score and Sales')


plt.show()

# %%
metacritic_w_sales[['Global', 'user_review_count']].corr()
# Out:
#                      Global  user_review_count
# Global             1.000000           0.578905
# user_review_count  0.578905           1.000000

# %%
# based on the graphs above we came to the following conclusions

# for the publishers bar chart we saw that the 20 most popular publishers had no real correlation
# to the sales of their games. Some sold well and others didnt

# for the 2 scatter plots we saw that the amount of users who reviewed the game heavily correlated
# to sales for the game whereas the actual rating those users gave it had much less correlation

# %%
fig, ax = plt.subplots()

# Add data: "height", "weight" as x-y, index as color
ax.scatter(metacritic_w_sales['Global'], metacritic_w_sales['metacritic_score'])

ax.set_xlabel("Unit sales in Millions")
ax.set_ylabel("Average Critic Score (Metacritic)")
ax.set_title('Relationship between Critic Score and Sales')


plt.show()

# %%
metacritic_w_sales[['Global', 'metacritic_score']].corr()
# Out:
#                     Global  metacritic_score
# Global            1.000000          0.398667
# metacritic_score  0.398667          1.000000

# %%
fig, ax = plt.subplots()

# Add data: "height", "weight" as x-y, index as color
ax.scatter(gamespot_w_sales['Global'], gamespot_w_sales['score'])

ax.set_xlabel("Unit sales in Millions")
ax.set_ylabel("Average Critic Score (Metacritic)")
ax.set_title('Relationship between Critic Score and Sales')


plt.show()

# %%
gamespot_w_sales[['Global', 'score']].corr()
# Out:
#           Global     score
# Global  1.000000  0.298152
# score   0.298152  1.000000

# %%
metacritic_w_users = metacritic_w_sales.loc[metacritic_w_sales['user_review_count'] > 10]

# %%
fig, ax = plt.subplots()

# Add data: "height", "weight" as x-y, index as color
ax.scatter(metacritic_w_users['Global'], metacritic_w_users['metacritic_score'])

ax.set_xlabel("Unit sales in Millions")
ax.set_ylabel("Average Critic Score (Metacritic)")
ax.set_title('Relationship between Critic Score and Sales')


plt.show()

# %%
gamespot_w_sales[['Global', 'score']].corr()
# Out:
#           Global     score
# Global  1.000000  0.298152
# score   0.298152  1.000000

# %%
# Above we got the correlation and scatter plot for the user review count and the total sales globally


# we found that all 3 had some correletion, betweeen .29 and .39 which is good but lower than the
# correlation with the user review count


# we also checked the user score only gor games with at least 5 reviews as an attempt to try and
# not skew the data with scores that have only 1 review and it was still lower than critic scores

# %%
# going forward we will sort by review count, find the most popular games by the review count 
# which could tell us which game could be turned into a movie

# %%
top_20_games_by_sales = metacritic_w_sales.sort_values('Global', ascending = False).head(20)
# Out:
#                                   Game  metacritic_score  \
# 322                 grand theft auto v                97
# 84                  call of duty: wwii                80
# 0                red dead redemption 2                97
# 66      call of duty: advanced warfare                81
# 264                      battlefield 1                87
# 10                           fallout 4                88
# 36                   halo 5: guardians                84
# 102     call of duty: infinite warfare                78
# 323                    forza horizon 3                91
# 272                            fifa 17                84
# 53      gears of war: ultimate edition                82
# 269  halo: the master chief collection                85
# 126                            destiny                75
# 35                      gears of war 4                84
# 42                             fifa 16                84
# 45                             fifa 18                83
# 20                           titanfall                86
# 99                call of duty: ghosts                78
# 5                            overwatch                91
# 81           tom clancy's the division                80
#
#      metacritic_review_count  user_score  user_review_count content_rating  \
# 322                       14         7.8             1087.0              M
# 84                        21         4.2              399.0              M
# 0                         33         7.7             2413.0              M
# 66                        53         5.5              921.0              M
# 264                       39         7.6              666.0              M
# 10                        39         6.5             1971.0              M
# 36                       101         6.4             2950.0              T
# 102                       18         3.7              415.0              M
# 323                       91         8.0             1052.0              E
# 272                       51         5.1              271.0              E
# 53                        74         7.6              673.0              M
# 269                       69         7.5             1479.0              M
# 126                       11         5.5             1760.0              T
# 35                        99         7.0             1322.0              M
# 42                        45         4.4              477.0              E
# 45                        21         3.1              204.0              E
# 20                        68         6.7             2485.0              M
# 99                         7         4.3              716.0              M
# 5                         18         5.9              886.0              T
# 81                        33         6.9              688.0              M
#
#                                                 genres  release_date    Year  \
# 322     ['Action Adventure', ' Modern', ' Open-World']  Nov 18, 2014  2014.0
# 84   ['Action', ' Shooter', ' First-Person', ' Arca...   Nov 3, 2017  2017.0
# 0                  ['Action Adventure', ' Open-World']  Oct 26, 2018  2018.0
# 66   ['Action', ' Shooter', ' First-Person', ' Mode...   Nov 3, 2014  2014.0
# 264  ['Action', ' General', ' Shooter', ' First-Per...  Oct 18, 2016  2016.0
# 10      ['General', ' Role-Playing', ' Western-Style']  Nov 10, 2015  2015.0
# 36   ['Shooter', ' Sci-Fi', ' Sci-Fi', ' Action', '...  Oct 27, 2015  2015.0
# 102  ['Action', ' Shooter', ' First-Person', ' Tact...   Nov 4, 2016  2016.0
# 323           ['Racing', ' Simulation', ' Automobile']  Sep 23, 2016  2016.0
# 272             ['Sports', ' Team', ' Soccer', ' Sim']  Sep 27, 2016  2016.0
# 53   ['Action', ' Shooter', ' Third-Person', ' Arca...  Aug 25, 2015  2015.0
# 269  ['Miscellaneous', ' Compilation', ' Action', '...  Nov 11, 2014  2014.0
# 126  ['Shooter', ' Sci-Fi', ' Action', ' Shooter', ...   Sep 9, 2014  2014.0
# 35   ['Action', ' Sci-Fi', ' Third-Person', ' Shoot...  Oct 11, 2016  2016.0
# 42              ['Sports', ' Team', ' Soccer', ' Sim']  Sep 22, 2015  2015.0
# 45              ['Sports', ' Team', ' Soccer', ' Sim']  Sep 26, 2017  2017.0
# 20   ['Shooter', ' Sci-Fi', ' Miscellaneous', ' Gen...  Mar 11, 2014  2014.0
# 99   ['Action', ' Shooter', ' Shooter', ' First-Per...  Nov 19, 2013  2013.0
# 5    ['Action', ' Shooter', ' First-Person', ' Tact...  May 23, 2016  2016.0
# 81   ['Shooter', ' Modern', ' Modern', ' Action', '...   Mar 8, 2016  2016.0
#
#                   Publisher  North America  Europe  Japan  Rest of World  \
# 322          Rockstar Games           4.70    3.25   0.01           0.76
# 84               Activision           3.75    1.91   0.00           0.57
# 0            Rockstar Games           3.76    1.47   0.00           0.54
# 66               Activision           3.25    1.49   0.01           0.48
# 264         Electronic Arts           3.37    1.26   0.02           0.48
# 10       Bethesda Softworks           2.94    1.62   0.02           0.45
# 36        Microsoft Studios           2.94    1.49   0.03           0.45
# 102              Activision           2.91    1.44   0.00           0.44
# 323       Microsoft Studios           1.64    1.96   0.02           0.32
# 272         Electronic Arts           1.04    2.40   0.00           0.27
# 53        Microsoft Studios           2.88    0.37   0.00           0.37
# 269       Microsoft Studios           2.06    1.04   0.03           0.31
# 126              Activision           2.17    0.92   0.00           0.32
# 35        Microsoft Studios           2.17    0.90   0.00           0.32
# 42                EA Sports           0.92    2.10   0.00           0.24
# 45                EA Sports           0.98    1.92   0.00           0.23
# 20          Electronic Arts           1.88    0.91   0.04           0.28
# 99               Activision           1.92    0.86   0.00           0.28
# 5    Blizzard Entertainment           1.63    0.84   0.00           0.25
# 81                  Ubisoft           1.54    0.82   0.00           0.24
#
#      Global
# 322    8.72
# 84     6.23
# 0      5.77
# 66     5.22
# 264    5.13
# 10     5.03
# 36     4.92
# 102    4.79
# 323    3.93
# 272    3.71
# 53     3.62
# 269    3.44
# 126    3.41
# 35     3.38
# 42     3.25
# 45     3.14
# 20     3.11
# 99     3.07
# 5      2.72
# 81     2.59

# %%
ax = top_20_games_by_sales.plot.bar(x = 'Game', y = 'user_review_count')
ax.set_ylabel('User Review Count')
ax.set_xlabel('Game')
ax.set_title('Review Count for Top 20 Games Sold')
# Out:
# Text(0.5, 1.0, 'Review Count for Top 20 Games Sold')

# %%
# based on the top 20 games sold most had a lot of reviews and the ones that didnt
# like fifa are games that have new releases every year

# %%
publisher_sales = metacritic_w_sales.groupby('content_rating')['Global'].describe().sort_values('count', ascending = False)[0:20]    

ax = publisher_sales.plot.bar(y = 'mean')
ax.set_ylabel('Unit sales in Millions')
ax.set_xlabel('Content Rating')
ax.set_title('Sales by Content Rating')
# Out:
# Text(0.5, 1.0, 'Top 20 Publishers vs Sales')

# %%
publisher_sales = metacritic_w_sales.groupby('content_rating')['user_review_count'].describe().sort_values('count', ascending = False)[0:20]    

ax = publisher_sales.plot.bar(y = 'mean')
ax.set_ylabel('Average User Review Count')
ax.set_xlabel('Content Rating')
ax.set_title('User Review Count by Content Rating')
# Out:
# Text(0.5, 1.0, 'User Review Count by Content Rating')

# %%
# Based on the graphs above the best selling and most reviewed games are Mature games by a large margin
